# %% [markdown]
# #  Consignes
#
# ## Description
#
# Ouvrir le fichier ks-projects-201801.csv, il recense environ 100 000 projets KickStarter. Intégrer les données directement avec L'API Python dans une base de données Mongo.
#
# Il conviendra de bien spécifier manuellement l'ID du document. Pensez aussi à bien formatter le type des données pour profiter des méthodes implémentées par Mongo. L'ensemble de données n'est pas forcément nécessaire, c'est à vous de créer votre modèle de données.
#
# ## Questions
#
# - 1) Récupérer les 5 projets ayant reçu le plus de promesse de dons.
# - 2) Compter le nombre de projets ayant atteint leur but.
# - 3) Compter le nombre de projets pour chaque catégorie.
# - 4) Compter le nombre de projets français ayant été instanciés avant 2016.
# - 5) Récupérer les projets américains ayant demandé plus de 200 000 dollars.
# - 6) Compter le nombre de projet ayant "Sport" dans leur nom

# %%
import pandas as pd
import pymongo
import numpy as np
import json

# %%
client = pymongo.MongoClient("mongo:27017")
database = client['exercices']
collection = database['kickstarter']

# %%
df_ks = pd.read_csv("./data/ks-projects-201801-sample.csv")
df_ks.head()
# Out:
# /usr/local/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3172: DtypeWarning: Columns (6,8,10,12) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#            ID                                               name  \
# 0   872782264    Scott Cooper's Solo CD "A Leg Trick" (Canceled)
# 1  1326492673                                    Ohceola jewelry
# 2  1688410639  Sluff Off & Harald: Two latest EGGs are Classi...
# 3   156812982  SketchPlanner: Create and Plan- all in one bea...
# 4  1835968190    Proven sales with custom motorcycle accessories
#
#          category main_category currency    deadline   goal  \
# 0            Rock         Music      USD  2011-09-16   2000
# 1         Fashion       Fashion      USD  2012-08-22  18000
# 2  Tabletop Games         Games      USD  2016-07-19   2000
# 3       Art Books    Publishing      USD  2017-09-27  13000
# 4       Sculpture           Art      CAD  2016-02-24   5000
#
#               launched pledged       state backers country usd pledged  \
# 0  2011-08-17 06:31:31    1145    canceled      24      US        1145
# 1  2012-07-23 20:46:48    1851      failed      28      US        1851
# 2  2016-07-01 21:55:54    7534  successful     254      US        3796
# 3  2017-08-28 15:47:02   16298  successful     367      US        2670
# 4  2016-01-25 17:37:10       1      failed       1      CA    0.708148
#
#    usd_pledged_real
# 0       1145.000000
# 1       1851.000000
# 2       7534.000000
# 3      16298.000000
# 4          0.738225

# %% [markdown]
# Ce warning intervient lorsque pandas n'arrive pas à inférer le type de données. Il est sympa il précise les colones 6,8,10,12.

# %%
df_ks.columns[[6,8,10,12]]
# Out:
# Index(['goal', 'pledged', 'backers', 'usd pledged'], dtype='object')

# %%
df_ks.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150000 entries, 0 to 149999
# Data columns (total 14 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   ID                150000 non-null  int64
#  1   name              149998 non-null  object
#  2   category          150000 non-null  object
#  3   main_category     150000 non-null  object
#  4   currency          150000 non-null  object
#  5   deadline          150000 non-null  object
#  6   goal              150000 non-null  object
#  7   launched          150000 non-null  object
#  8   pledged           150000 non-null  object
#  9   state             150000 non-null  object
#  10  backers           150000 non-null  object
#  11  country           150000 non-null  object
#  12  usd pledged       148518 non-null  object
#  13  usd_pledged_real  150000 non-null  float64
# dtypes: float64(1), int64(1), object(12)
# memory usage: 16.0+ MB

# %% [markdown]
# ## Question 0

# %% [markdown]
# ### Nettoyer les données

# %%
# Comme vu précédemment, nous avons des colonnes qui nous posent problèmes,
# nous allons donc supprimer dans ces colonnes les valeurs qui posent problème,
# puis nous allons convertir leurs valeurs en les types qui correspondent

# %%
df_ks = df_ks[df_ks['goal'].astype(str).str.contains('.', na=False, regex=False)]

# %%
df_ks['goal']= df_ks['goal'].astype(float)

# %%
df_ks = df_ks[df_ks['pledged'].astype(str).str.contains('.', na=False, regex=False)]

# %%
df_ks['pledged']= df_ks['pledged'].astype(float)

# %%
df_ks['backers']= df_ks['backers'].astype(int)

# %%
df_ks = df_ks[df_ks['usd pledged'].astype(str).str.contains('.', na=False, regex=False)]

# %%
df_ks['usd pledged']= df_ks['usd pledged'].astype(float)

# %%
df_ks.info()
df_ks
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 148517 entries, 0 to 149999
# Data columns (total 14 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   ID                148517 non-null  int64
#  1   name              148515 non-null  object
#  2   category          148517 non-null  object
#  3   main_category     148517 non-null  object
#  4   currency          148517 non-null  object
#  5   deadline          148517 non-null  object
#  6   goal              148517 non-null  float64
#  7   launched          148517 non-null  object
#  8   pledged           148517 non-null  float64
#  9   state             148517 non-null  object
#  10  backers           148517 non-null  int64
#  11  country           148517 non-null  object
#  12  usd pledged       148517 non-null  float64
#  13  usd_pledged_real  148517 non-null  float64
# dtypes: float64(4), int64(2), object(8)
# memory usage: 17.0+ MB
#                 ID                                               name  \
# 0        872782264    Scott Cooper's Solo CD "A Leg Trick" (Canceled)
# 1       1326492673                                    Ohceola jewelry
# 2       1688410639  Sluff Off & Harald: Two latest EGGs are Classi...
# 3        156812982  SketchPlanner: Create and Plan- all in one bea...
# 4       1835968190    Proven sales with custom motorcycle accessories
# ...            ...                                                ...
# 149995   574841011  Scutes Headphones - A new way to listen to you...
# 149996   235190237                               My Drunk @$$ Reviews
# 149997   758540498          Freedom Planet - High Speed Platform Game
# 149998  1624952469                                      Clown vs Mime
# 149999   891117261                            Striker's Cafe & Bakery
#
#               category main_category currency    deadline     goal  \
# 0                 Rock         Music      USD  2011-09-16   2000.0
# 1              Fashion       Fashion      USD  2012-08-22  18000.0
# 2       Tabletop Games         Games      USD  2016-07-19   2000.0
# 3            Art Books    Publishing      USD  2017-09-27  13000.0
# 4            Sculpture           Art      CAD  2016-02-24   5000.0
# ...                ...           ...      ...         ...      ...
# 149995  Product Design        Design      USD  2014-11-14  40000.0
# 149996       Webseries  Film & Video      USD  2012-05-18   1000.0
# 149997     Video Games         Games      USD  2013-02-15   2000.0
# 149998       Webseries  Film & Video      USD  2011-05-27   1000.0
# 149999     Food Trucks          Food      USD  2016-05-02  20000.0
#
#                    launched   pledged       state  backers country  \
# 0       2011-08-17 06:31:31   1145.00    canceled       24      US
# 1       2012-07-23 20:46:48   1851.00      failed       28      US
# 2       2016-07-01 21:55:54   7534.00  successful      254      US
# 3       2017-08-28 15:47:02  16298.00  successful      367      US
# 4       2016-01-25 17:37:10      1.00      failed        1      CA
# ...                     ...       ...         ...      ...     ...
# 149995  2014-10-14 20:44:37   3664.00    canceled       43      US
# 149996  2012-04-18 04:42:47      0.00      failed        0      US
# 149997  2013-01-16 00:53:32  25472.69  successful     1105      US
# 149998  2011-04-27 01:22:52     76.00      failed        3      US
# 149999  2016-04-03 08:01:57     29.00      failed        3      US
#
#          usd pledged  usd_pledged_real
# 0        1145.000000       1145.000000
# 1        1851.000000       1851.000000
# 2        3796.000000       7534.000000
# 3        2670.000000      16298.000000
# 4           0.708148          0.738225
# ...              ...               ...
# 149995   3664.000000       3664.000000
# 149996      0.000000          0.000000
# 149997  25472.690000      25472.690000
# 149998     76.000000         76.000000
# 149999     29.000000         29.000000
#
# [148517 rows x 14 columns]

# %%
# Etant donné qu'il y a beaucoup de données
# nous pouvont récupérer qu'une partie des données,
# comme par exemple les projets ayant réussi ou sont en cours

# %%
df_ks['state'].unique()
# Out:
# array(['canceled', 'failed', 'successful', 'live', 'suspended'],
#       dtype=object)

# %%
# df_ks= df_ks[df_ks['state'].isin(['successful', 'live'])]
# df_ks

# %% [markdown]
# ### Importer les données

# %%
# On choisit les identifiants
df_ks= df_ks.rename(columns={"ID":"_id"})

# %%
payload = json.loads(df_ks.to_json(orient='records'))
collection.delete_many({}) #pour nettoyer la collection
collection.insert_many(payload)

# %%
collection.find_one()
# Out:
# {'_id': 872782264,
#  'name': 'Scott Cooper\'s Solo CD "A Leg Trick" (Canceled)',
#  'category': 'Rock',
#  'main_category': 'Music',
#  'currency': 'USD',
#  'deadline': '2011-09-16',
#  'goal': 2000.0,
#  'launched': '2011-08-17 06:31:31',
#  'pledged': 1145.0,
#  'state': 'canceled',
#  'backers': 24,
#  'country': 'US',
#  'usd pledged': 1145.0,
#  'usd_pledged_real': 1145.0}

# %% [markdown]
# ## Question 1

# %%
# 5 projets ayant reçu le plus de promesse de dons
cur= collection.find().sort([("pledged",-1)]).limit(5)
list(cur)
# Out:
# [{'_id': 342886736,
#   'name': "COOLEST COOLER: 21st Century Cooler that's Actually Cooler",
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'currency': 'USD',
#   'deadline': '2014-08-30',
#   'goal': 50000.0,
#   'launched': '2014-07-08 10:14:37',
#   'pledged': 13285226.36,
#   'state': 'successful',
#   'backers': 62642,
#   'country': 'US',
#   'usd pledged': 13285226.36,
#   'usd_pledged_real': 13285226.36},
#  {'_id': 2103598555,
#   'name': 'Pebble 2, Time 2 + All-New Pebble Core',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'currency': 'USD',
#   'deadline': '2016-06-30',
#   'goal': 1000000.0,
#   'launched': '2016-05-24 15:49:52',
#   'pledged': 12779843.49,
#   'state': 'successful',
#   'backers': 66673,
#   'country': 'US',
#   'usd pledged': 12779843.49,
#   'usd_pledged_real': 12779843.49},
#  {'_id': 2111201788,
#   'name': 'Expect the Unexpected. digiFilmï¿½ Camera by YASHICA',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'currency': 'HKD',
#   'deadline': '2017-11-19',
#   'goal': 800000.0,
#   'launched': '2017-10-10 12:52:25',
#   'pledged': 10035296.0,
#   'state': 'successful',
#   'backers': 6935,
#   'country': 'HK',
#   'usd pledged': 4788.64216028,
#   'usd_pledged_real': 1285142.981546224},
#  {'_id': 1033978702,
#   'name': 'OUYA: A New Kind of Video Game Console',
#   'category': 'Gaming Hardware',
#   'main_category': 'Games',
#   'currency': 'USD',
#   'deadline': '2012-08-09',
#   'goal': 950000.0,
#   'launched': '2012-07-10 14:44:41',
#   'pledged': 8596474.58,
#   'state': 'successful',
#   'backers': 63416,
#   'country': 'US',
#   'usd pledged': 8596474.58,
#   'usd_pledged_real': 8596474.58},
#  {'_id': 450099426,
#   'name': 'The Everyday Backpack, Tote, and Sling',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'currency': 'USD',
#   'deadline': '2016-09-10',
#   'goal': 500000.0,
#   'launched': '2016-07-13 00:47:35',
#   'pledged': 6565782.5,
#   'state': 'successful',
#   'backers': 26359,
#   'country': 'US',
#   'usd pledged': 1462611.0,
#   'usd_pledged_real': 6565782.5}]

# %% [markdown]
# ## Question 2

# %%
# nombre de projets ayant atteint leur but
nb_successful = collection.find({"state":"successful"}).count()
nb_successful
# Out:
# /tmp/ipykernel_12/3143706418.py:2: DeprecationWarning: count is deprecated. Use Collection.count_documents instead.
#   nb_successful = collection.find({"state":"successful"}).count()
# 52998

# %% [markdown]
# ## Question 3

# %%
# nombre de projets pour chaque catégorie
cur= collection.aggregate([
    {"$group" : {
        "_id" : "$main_category",
        "number_projects" : {"$sum" : 1}
    }}
])
list(cur)
# Out:
# [{'_id': 'Dance', 'number_projects': 1488},
#  {'_id': 'Food', 'number_projects': 9805},
#  {'_id': 'Theater', 'number_projects': 4305},
#  {'_id': 'Art', 'number_projects': 11260},
#  {'_id': 'Crafts', 'number_projects': 3463},
#  {'_id': 'Music', 'number_projects': 19657},
#  {'_id': 'Film & Video', 'number_projects': 24983},
#  {'_id': 'Design', 'number_projects': 11911},
#  {'_id': 'Fashion', 'number_projects': 8943},
#  {'_id': 'Photography', 'number_projects': 4176},
#  {'_id': 'Journalism', 'number_projects': 1807},
#  {'_id': 'Publishing', 'number_projects': 15721},
#  {'_id': 'Games', 'number_projects': 13988},
#  {'_id': 'Technology', 'number_projects': 12871},
#  {'_id': 'Comics', 'number_projects': 4139}]

# %% [markdown]
# ## Question 4

# %%
# nombre de projets français ayant été instanciés avant 2016
nb_fr_before_2016 = collection.find({
    "$and":[
        {"country" : "FR"},
        {"launched" : {"$lte" : "2016-01-01 00:00:00"}}
    ]
})
nb_fr_before_2016 = nb_fr_before_2016.count()
nb_fr_before_2016
# Out:
# /tmp/ipykernel_12/197053112.py:8: DeprecationWarning: count is deprecated. Use Collection.count_documents instead.
#   nb_fr_before_2016 = nb_fr_before_2016.count()
# 330

# %% [markdown]
# ## Question 5

# %%
# projets américains ayant demandé plus de 200 000 dollars
cur = collection.find({
    "$and":[
        {"country" : "US"},
        {"goal" : {"$gte" : 200000}}
    ]
})
list(cur)
# Out:
# [{'_id': 655043686,
#   'name': 'Far from Par is a movie about a man and a talking golf ball.',
#   'category': 'Comedy',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2014-12-05',
#   'goal': 200000.0,
#   'launched': '2014-10-06 21:20:06',
#   'pledged': 10.0,
#   'state': 'failed',
#   'backers': 2,
#   'country': 'US',
#   'usd pledged': 10.0,
#   'usd_pledged_real': 10.0},
#  {'_id': 866634482,
#   'name': 'A CALL TO ADVENTURE',
#   'category': 'Film & Video',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2012-09-14',
#   'goal': 287000.0,
#   'launched': '2012-08-13 23:14:02',
#   'pledged': 1465.0,
#   'state': 'failed',
#   'backers': 11,
#   'country': 'US',
#   'usd pledged': 1465.0,
#   'usd_pledged_real': 1465.0},
#  {'_id': 993194166,
#   'name': 'Storybricks, the storytelling online RPG',
#   'category': 'Video Games',
#   'main_category': 'Games',
#   'currency': 'USD',
#   'deadline': '2012-06-01',
#   'goal': 250000.0,
#   'launched': '2012-05-01 20:49:58',
#   'pledged': 23680.54,
#   'state': 'failed',
#   'backers': 409,
#   'country': 'US',
#   'usd pledged': 23680.54,
#   'usd_pledged_real': 23680.54},
#  {'_id': 1147175344,
#   'name': 'Shine On New World',
#   'category': 'Theater',
#   'main_category': 'Theater',
#   'currency': 'USD',
#   'deadline': '2013-11-04',
#   'goal': 300000.0,
#   'launched': '2013-09-30 18:18:40',
#   'pledged': 12314.0,
#   'state': 'failed',
#   'backers': 50,
#   'country': 'US',
#   'usd pledged': 12314.0,
#   'usd_pledged_real': 12314.0},
#  {'_id': 2012810303,
#   'name': 'Nightclub',
#   'category': 'Music',
#   'main_category': 'Music',
#   'currency': 'USD',
#   'deadline': '2017-09-10',
#   'goal': 3000000.0,
#   'launched': '2017-08-11 18:08:07',
#   'pledged': 1.0,
#   'state': 'failed',
#   'backers': 1,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 1.0},
#  {'_id': 593221398,
#   'name': 'Nastaran (Wild Rose)',
#   'category': 'Documentary',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2015-06-30',
#   'goal': 250000.0,
#   'launched': '2015-05-08 21:03:20',
#   'pledged': 0.0,
#   'state': 'failed',
#   'backers': 0,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': 621936552,
#   'name': 'Hubo - Extension Box for iPhone',
#   'category': 'Gadgets',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2016-11-26',
#   'goal': 250000.0,
#   'launched': '2016-10-27 17:43:14',
#   'pledged': 1996.0,
#   'state': 'failed',
#   'backers': 10,
#   'country': 'US',
#   'usd pledged': 438.0,
#   'usd_pledged_real': 1996.0},
#  {'_id': 1323150226,
#   'name': 'Baja ATV Park (Suspended)',
#   'category': 'Live Games',
#   'main_category': 'Games',
#   'currency': 'USD',
#   'deadline': '2016-05-31',
#   'goal': 300000.0,
#   'launched': '2016-04-01 22:04:54',
#   'pledged': 11.0,
#   'state': 'suspended',
#   'backers': 3,
#   'country': 'US',
#   'usd pledged': 11.0,
#   'usd_pledged_real': 11.0},
#  {'_id': 61436443,
#   'name': 'Chihuly Installation for Orlando (Pulse Nightclub)',
#   'category': 'Installations',
#   'main_category': 'Art',
#   'currency': 'USD',
#   'deadline': '2016-08-12',
#   'goal': 1000000.0,
#   'launched': '2016-07-13 17:31:26',
#   'pledged': 5.0,
#   'state': 'failed',
#   'backers': 3,
#   'country': 'US',
#   'usd pledged': 4.0,
#   'usd_pledged_real': 5.0},
#  {'_id': 821637012,
#   'name': 'Kurt Vonnegut: Unstuck in Time',
#   'category': 'Documentary',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2015-03-10',
#   'goal': 250000.0,
#   'launched': '2015-02-10 14:05:34',
#   'pledged': 300319.0,
#   'state': 'successful',
#   'backers': 3755,
#   'country': 'US',
#   'usd pledged': 300319.0,
#   'usd_pledged_real': 300319.0},
#  {'_id': 924370408,
#   'name': 'The LAKE HOPPER is a VTOL Flying Water Craft Made in America',
#   'category': 'Flight',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2016-12-15',
#   'goal': 3000000.0,
#   'launched': '2016-11-15 21:06:46',
#   'pledged': 0.0,
#   'state': 'failed',
#   'backers': 0,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': 966762561,
#   'name': '"Hill" (11 For 11) (From the writer of Rudy & Hoosiers)',
#   'category': 'Film & Video',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2012-12-12',
#   'goal': 1000000.0,
#   'launched': '2012-11-12 23:27:51',
#   'pledged': 0.0,
#   'state': 'failed',
#   'backers': 0,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': 673847752,
#   'name': 'Saints of The Classroom',
#   'category': 'Television',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2016-11-18',
#   'goal': 250000.0,
#   'launched': '2016-10-19 02:05:16',
#   'pledged': 3085.0,
#   'state': 'failed',
#   'backers': 24,
#   'country': 'US',
#   'usd pledged': 1915.0,
#   'usd_pledged_real': 3085.0},
#  {'_id': 1751772364,
#   'name': 'Hemingwrite - A Distraction Free Digital Typewriter',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'currency': 'USD',
#   'deadline': '2015-01-23',
#   'goal': 250000.0,
#   'launched': '2014-12-10 18:58:08',
#   'pledged': 342471.0,
#   'state': 'successful',
#   'backers': 1096,
#   'country': 'US',
#   'usd pledged': 342471.0,
#   'usd_pledged_real': 342471.0},
#  {'_id': 1529289950,
#   'name': 'Breakfast 24/7',
#   'category': 'Food',
#   'main_category': 'Food',
#   'currency': 'USD',
#   'deadline': '2016-07-02',
#   'goal': 1000000.0,
#   'launched': '2016-05-18 00:36:35',
#   'pledged': 0.0,
#   'state': 'failed',
#   'backers': 0,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': 314981144,
#   'name': 'FJE REVOLT',
#   'category': 'Apparel',
#   'main_category': 'Fashion',
#   'currency': 'USD',
#   'deadline': '2015-02-10',
#   'goal': 500000.0,
#   'launched': '2015-01-14 03:01:52',
#   'pledged': 0.0,
#   'state': 'failed',
#   'backers': 0,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': 208383561,
#   'name': 'Austin City Limits 40 Year History Documentary Film',
#   'category': 'Documentary',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2014-09-30',
#   'goal': 400000.0,
#   'launched': '2014-08-29 20:46:59',
#   'pledged': 9.0,
#   'state': 'failed',
#   'backers': 1,
#   'country': 'US',
#   'usd pledged': 9.0,
#   'usd_pledged_real': 9.0},
#  {'_id': 912070501,
#   'name': 'Ozark Mountain Ranch',
#   'category': 'Film & Video',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2015-04-06',
#   'goal': 466000.0,
#   'launched': '2015-02-10 19:11:52',
#   'pledged': 1076.0,
#   'state': 'failed',
#   'backers': 5,
#   'country': 'US',
#   'usd pledged': 1076.0,
#   'usd_pledged_real': 1076.0},
#  {'_id': 2116069761,
#   'name': 'STEM Lesson Plan - BotBrainï¿½ Educational Products',
#   'category': 'Software',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2014-10-07',
#   'goal': 279646.0,
#   'launched': '2014-09-04 18:26:25',
#   'pledged': 85.0,
#   'state': 'failed',
#   'backers': 7,
#   'country': 'US',
#   'usd pledged': 85.0,
#   'usd_pledged_real': 85.0},
#  {'_id': 410799527,
#   'name': 'Guitar Godz VR: A 3D Rock Music Game',
#   'category': 'Video Games',
#   'main_category': 'Games',
#   'currency': 'USD',
#   'deadline': '2017-04-04',
#   'goal': 500000.0,
#   'launched': '2017-03-28 19:00:52',
#   'pledged': 22612.0,
#   'state': 'failed',
#   'backers': 36,
#   'country': 'US',
#   'usd pledged': 12311.0,
#   'usd_pledged_real': 22612.0},
#  {'_id': 848767036,
#   'name': "The world's first crowd funded millionaire documentary",
#   'category': 'Documentary',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2015-05-24',
#   'goal': 1000000.0,
#   'launched': '2015-04-24 02:58:26',
#   'pledged': 171.0,
#   'state': 'failed',
#   'backers': 17,
#   'country': 'US',
#   'usd pledged': 171.0,
#   'usd_pledged_real': 171.0},
#  {'_id': 1520402606,
#   'name': 'Creating an online game, "Perdition Online".',
#   'category': 'Video Games',
#   'main_category': 'Games',
#   'currency': 'USD',
#   'deadline': '2013-11-15',
#   'goal': 350000.0,
#   'launched': '2013-09-16 22:49:11',
#   'pledged': 16.0,
#   'state': 'failed',
#   'backers': 2,
#   'country': 'US',
#   'usd pledged': 16.0,
#   'usd_pledged_real': 16.0},
#  {'_id': 376621995,
#   'name': 'The Adventures of Billy Buskirk',
#   'category': 'Family',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2017-10-14',
#   'goal': 750000.0,
#   'launched': '2017-08-15 19:49:31',
#   'pledged': 1.0,
#   'state': 'failed',
#   'backers': 1,
#   'country': 'US',
#   'usd pledged': 1.0,
#   'usd_pledged_real': 1.0},
#  {'_id': 1227415659,
#   'name': 'MY TINSEL TOWN (Canceled)',
#   'category': 'Apps',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2014-09-13',
#   'goal': 577000.0,
#   'launched': '2014-07-15 00:55:45',
#   'pledged': 0.0,
#   'state': 'canceled',
#   'backers': 0,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': 520101512,
#   'name': 'Moonlight 5 star (Canceled)',
#   'category': 'Restaurants',
#   'main_category': 'Food',
#   'currency': 'USD',
#   'deadline': '2016-06-18',
#   'goal': 250000.0,
#   'launched': '2016-04-19 06:41:47',
#   'pledged': 0.0,
#   'state': 'canceled',
#   'backers': 0,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': 1681174007,
#   'name': 'TOMB Adventure 2',
#   'category': 'Games',
#   'main_category': 'Games',
#   'currency': 'USD',
#   'deadline': '2012-07-16',
#   'goal': 200000.0,
#   'launched': '2012-06-08 16:54:47',
#   'pledged': 5740.0,
#   'state': 'failed',
#   'backers': 54,
#   'country': 'US',
#   'usd pledged': 5740.0,
#   'usd_pledged_real': 5740.0},
#  {'_id': 1038309030,
#   'name': 'The EIFLE S Smart-Mirror W/Front-Facing Camera! (Canceled)',
#   'category': 'Software',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2016-03-25',
#   'goal': 200000.0,
#   'launched': '2016-01-25 15:17:42',
#   'pledged': 4248.0,
#   'state': 'canceled',
#   'backers': 16,
#   'country': 'US',
#   'usd pledged': 4248.0,
#   'usd_pledged_real': 4248.0},
#  {'_id': 1496553278,
#   'name': 'The Brick Cafe',
#   'category': 'Food',
#   'main_category': 'Food',
#   'currency': 'USD',
#   'deadline': '2016-03-01',
#   'goal': 200000.0,
#   'launched': '2016-01-28 17:43:17',
#   'pledged': 0.0,
#   'state': 'failed',
#   'backers': 0,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': 1256627633,
#   'name': 'Dangerous Seas: A Beautiful Under Water War App (Canceled)',
#   'category': 'Mobile Games',
#   'main_category': 'Games',
#   'currency': 'USD',
#   'deadline': '2016-06-26',
#   'goal': 400000.0,
#   'launched': '2016-05-27 17:52:03',
#   'pledged': 146.0,
#   'state': 'canceled',
#   'backers': 3,
#   'country': 'US',
#   'usd pledged': 146.0,
#   'usd_pledged_real': 146.0},
#  {'_id': 2033979252,
#   'name': 'ViewCoze.com | Cozy viewing from home (Canceled)',
#   'category': 'Web',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2016-02-01',
#   'goal': 370000.0,
#   'launched': '2015-12-10 23:55:54',
#   'pledged': 80.0,
#   'state': 'canceled',
#   'backers': 1,
#   'country': 'US',
#   'usd pledged': 80.0,
#   'usd_pledged_real': 80.0},
#  {'_id': 1751639331,
#   'name': 'Meet kubo: an electric scooter to carry all your stuff!',
#   'category': 'Hardware',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2013-12-20',
#   'goal': 300000.0,
#   'launched': '2013-11-20 06:00:07',
#   'pledged': 56667.0,
#   'state': 'failed',
#   'backers': 166,
#   'country': 'US',
#   'usd pledged': 56667.0,
#   'usd_pledged_real': 56667.0},
#  {'_id': 1178067412,
#   'name': 'ONEIDNET Social Professional Commercial Corporate Platform',
#   'category': 'Web',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2017-03-24',
#   'goal': 545539.0,
#   'launched': '2017-02-22 19:24:24',
#   'pledged': 1.0,
#   'state': 'failed',
#   'backers': 1,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 1.0},
#  {'_id': 175370281,
#   'name': 'Civilian Cam',
#   'category': 'Technology',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2015-10-06',
#   'goal': 200000.0,
#   'launched': '2015-08-07 22:42:57',
#   'pledged': 10.0,
#   'state': 'failed',
#   'backers': 1,
#   'country': 'US',
#   'usd pledged': 10.0,
#   'usd_pledged_real': 10.0},
#  {'_id': 499583381,
#   'name': 'The Scariest Movie Ever Created',
#   'category': 'Horror',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2015-08-22',
#   'goal': 100000000.0,
#   'launched': '2015-07-23 21:44:02',
#   'pledged': 1.0,
#   'state': 'failed',
#   'backers': 1,
#   'country': 'US',
#   'usd pledged': 1.0,
#   'usd_pledged_real': 1.0},
#  {'_id': 290390319,
#   'name': 'The SEED Project',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'currency': 'USD',
#   'deadline': '2013-01-17',
#   'goal': 250000.0,
#   'launched': '2012-12-18 23:01:12',
#   'pledged': 35.0,
#   'state': 'failed',
#   'backers': 2,
#   'country': 'US',
#   'usd pledged': 35.0,
#   'usd_pledged_real': 35.0},
#  {'_id': 1560972255,
#   'name': 'NewsRadio Season 6 (Canceled)',
#   'category': 'Television',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2015-12-16',
#   'goal': 3000000.0,
#   'launched': '2015-10-17 00:40:32',
#   'pledged': 101.0,
#   'state': 'canceled',
#   'backers': 2,
#   'country': 'US',
#   'usd pledged': 101.0,
#   'usd_pledged_real': 101.0},
#  {'_id': 1876072493,
#   'name': 'Get Me Me Kids (Books, Music, Film & Games)',
#   'category': "Children's Books",
#   'main_category': 'Publishing',
#   'currency': 'USD',
#   'deadline': '2015-10-10',
#   'goal': 500000.0,
#   'launched': '2015-09-10 22:58:39',
#   'pledged': 0.0,
#   'state': 'failed',
#   'backers': 0,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': 1517530930,
#   'name': "Daniel's Dream",
#   'category': 'Film & Video',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2013-06-21',
#   'goal': 2000000.0,
#   'launched': '2013-05-22 22:02:09',
#   'pledged': 60.0,
#   'state': 'failed',
#   'backers': 2,
#   'country': 'US',
#   'usd pledged': 60.0,
#   'usd_pledged_real': 60.0},
#  {'_id': 658943325,
#   'name': 'iFly Hand Held Camera Crane- pan AND tilt - iPhone GoPro etc',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'currency': 'USD',
#   'deadline': '2012-12-16',
#   'goal': 444000.0,
#   'launched': '2012-11-05 19:05:56',
#   'pledged': 3439.0,
#   'state': 'failed',
#   'backers': 11,
#   'country': 'US',
#   'usd pledged': 3439.0,
#   'usd_pledged_real': 3439.0},
#  {'_id': 420095150,
#   'name': 'GolferVox',
#   'category': 'Apps',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2015-07-23',
#   'goal': 1200000.0,
#   'launched': '2015-06-23 21:12:43',
#   'pledged': 70.0,
#   'state': 'failed',
#   'backers': 2,
#   'country': 'US',
#   'usd pledged': 70.0,
#   'usd_pledged_real': 70.0},
#  {'_id': 668413973,
#   'name': 'Power Rangers | fan film reboot movie',
#   'category': 'Action',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2016-02-06',
#   'goal': 400000.0,
#   'launched': '2015-12-08 21:34:39',
#   'pledged': 0.0,
#   'state': 'failed',
#   'backers': 0,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': 1481048815,
#   'name': '"Another Network" Film Project',
#   'category': 'Narrative Film',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2014-05-15',
#   'goal': 225000.0,
#   'launched': '2014-03-31 22:46:31',
#   'pledged': 55.0,
#   'state': 'failed',
#   'backers': 3,
#   'country': 'US',
#   'usd pledged': 55.0,
#   'usd_pledged_real': 55.0},
#  {'_id': 1916952451,
#   'name': 'SELF-SUSTAINING ORGANIC FARM',
#   'category': 'Farms',
#   'main_category': 'Food',
#   'currency': 'USD',
#   'deadline': '2014-12-09',
#   'goal': 450000.0,
#   'launched': '2014-10-10 17:48:13',
#   'pledged': 11.0,
#   'state': 'failed',
#   'backers': 2,
#   'country': 'US',
#   'usd pledged': 11.0,
#   'usd_pledged_real': 11.0},
#  {'_id': 1554575493,
#   'name': 'Fuel-X-Tender',
#   'category': 'Gadgets',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2014-07-31',
#   'goal': 500000.0,
#   'launched': '2014-07-01 04:18:43',
#   'pledged': 272.0,
#   'state': 'failed',
#   'backers': 6,
#   'country': 'US',
#   'usd pledged': 272.0,
#   'usd_pledged_real': 272.0},
#  {'_id': 1601085300,
#   'name': 'Salad Barr ( the new fast food restaurant )',
#   'category': 'Restaurants',
#   'main_category': 'Food',
#   'currency': 'USD',
#   'deadline': '2016-03-26',
#   'goal': 270000.0,
#   'launched': '2016-02-26 00:04:18',
#   'pledged': 1.0,
#   'state': 'failed',
#   'backers': 1,
#   'country': 'US',
#   'usd pledged': 1.0,
#   'usd_pledged_real': 1.0},
#  {'_id': 1636574067,
#   'name': 'We want your money (Suspended)',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'currency': 'USD',
#   'deadline': '2016-08-03',
#   'goal': 300000.0,
#   'launched': '2016-06-04 16:51:18',
#   'pledged': 123.0,
#   'state': 'suspended',
#   'backers': 3,
#   'country': 'US',
#   'usd pledged': 123.0,
#   'usd_pledged_real': 123.0},
#  {'_id': 773987836,
#   'name': "Dutch's Kegs",
#   'category': 'Small Batch',
#   'main_category': 'Food',
#   'currency': 'USD',
#   'deadline': '2015-12-22',
#   'goal': 1000000.0,
#   'launched': '2015-11-17 23:36:06',
#   'pledged': 260.0,
#   'state': 'failed',
#   'backers': 17,
#   'country': 'US',
#   'usd pledged': 260.0,
#   'usd_pledged_real': 260.0},
#  {'_id': 1831435950,
#   'name': 'Pro Tailgater Party Plate',
#   'category': 'Gadgets',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2017-05-31',
#   'goal': 365000.0,
#   'launched': '2017-04-25 21:25:17',
#   'pledged': 200.0,
#   'state': 'failed',
#   'backers': 4,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 200.0},
#  {'_id': 178255149,
#   'name': 'Gabriel Device - Free energy for everyone',
#   'category': 'Hardware',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2017-12-14',
#   'goal': 500000.0,
#   'launched': '2017-11-14 01:35:25',
#   'pledged': 81.0,
#   'state': 'failed',
#   'backers': 3,
#   'country': 'US',
#   'usd pledged': 40.0,
#   'usd_pledged_real': 81.0},
#  {'_id': 1098261281,
#   'name': 'Pallet Wars, Part 1...Two More Weeks and Billions Are Ours!!',
#   'category': 'Narrative Film',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2017-11-30',
#   'goal': 875000.0,
#   'launched': '2017-10-31 06:35:30',
#   'pledged': 5.0,
#   'state': 'canceled',
#   'backers': 1,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 5.0},
#  {'_id': 849179016,
#   'name': 'Fast Easy Lightweight Modular Cabinets PhastPhurniture',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'currency': 'USD',
#   'deadline': '2017-04-25',
#   'goal': 250000.0,
#   'launched': '2017-03-11 03:10:44',
#   'pledged': 710.0,
#   'state': 'failed',
#   'backers': 5,
#   'country': 'US',
#   'usd pledged': 200.0,
#   'usd_pledged_real': 710.0},
#  {'_id': 1855118124,
#   'name': 'Sonic Chao World fan game (Canceled)',
#   'category': 'Games',
#   'main_category': 'Games',
#   'currency': 'USD',
#   'deadline': '2015-02-14',
#   'goal': 1000000.0,
#   'launched': '2015-01-15 23:33:34',
#   'pledged': 0.0,
#   'state': 'canceled',
#   'backers': 0,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': 326838990,
#   'name': 'StreamStick: The Future of Streaming TV and Media (Canceled)',
#   'category': 'Hardware',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2015-08-17',
#   'goal': 200000.0,
#   'launched': '2015-07-08 18:42:07',
#   'pledged': 4433.0,
#   'state': 'canceled',
#   'backers': 26,
#   'country': 'US',
#   'usd pledged': 4433.0,
#   'usd_pledged_real': 4433.0},
#  {'_id': 607916149,
#   'name': 'The Darkest Dawn',
#   'category': 'Narrative Film',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2013-06-28',
#   'goal': 500000.0,
#   'launched': '2013-05-29 04:48:42',
#   'pledged': 5.0,
#   'state': 'failed',
#   'backers': 1,
#   'country': 'US',
#   'usd pledged': 5.0,
#   'usd_pledged_real': 5.0},
#  {'_id': 696960534,
#   'name': 'Adventure Combat Ops - A real life, apocalyptic video game!',
#   'category': 'Live Games',
#   'main_category': 'Games',
#   'currency': 'USD',
#   'deadline': '2014-07-24',
#   'goal': 400000.0,
#   'launched': '2014-06-24 01:26:37',
#   'pledged': 320.0,
#   'state': 'failed',
#   'backers': 5,
#   'country': 'US',
#   'usd pledged': 320.0,
#   'usd_pledged_real': 320.0},
#  {'_id': 966045318,
#   'name': 'Haboob Wind - The Movie',
#   'category': 'Drama',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2017-12-31',
#   'goal': 200000.0,
#   'launched': '2017-11-16 19:49:52',
#   'pledged': 125.0,
#   'state': 'failed',
#   'backers': 2,
#   'country': 'US',
#   'usd pledged': 100.0,
#   'usd_pledged_real': 125.0},
#  {'_id': 2053440575,
#   'name': "World's First Smart Football",
#   'category': 'Technology',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2015-05-03',
#   'goal': 500000.0,
#   'launched': '2015-04-03 01:17:58',
#   'pledged': 1.0,
#   'state': 'failed',
#   'backers': 1,
#   'country': 'US',
#   'usd pledged': 1.0,
#   'usd_pledged_real': 1.0},
#  {'_id': 397353040,
#   'name': 'The Maryanne Godboldo Story (Canceled)',
#   'category': 'Narrative Film',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2013-07-20',
#   'goal': 250000.0,
#   'launched': '2013-06-20 01:17:50',
#   'pledged': 2350.0,
#   'state': 'canceled',
#   'backers': 45,
#   'country': 'US',
#   'usd pledged': 2350.0,
#   'usd_pledged_real': 2350.0},
#  {'_id': 534082236,
#   'name': 'M.A.C.S. (Canceled)',
#   'category': 'Space Exploration',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2014-12-08',
#   'goal': 400000.0,
#   'launched': '2014-10-24 20:53:50',
#   'pledged': 8.0,
#   'state': 'canceled',
#   'backers': 4,
#   'country': 'US',
#   'usd pledged': 8.0,
#   'usd_pledged_real': 8.0},
#  {'_id': 1733658269,
#   'name': 'Keeping my best friends dream alive after losing to cancer',
#   'category': 'DIY',
#   'main_category': 'Crafts',
#   'currency': 'USD',
#   'deadline': '2014-08-13',
#   'goal': 200000.0,
#   'launched': '2014-07-14 16:23:40',
#   'pledged': 5.0,
#   'state': 'failed',
#   'backers': 1,
#   'country': 'US',
#   'usd pledged': 5.0,
#   'usd_pledged_real': 5.0},
#  {'_id': 1957695328,
#   'name': 'Planetary Annihilation - A Next Generation RTS',
#   'category': 'Video Games',
#   'main_category': 'Games',
#   'currency': 'USD',
#   'deadline': '2012-09-14',
#   'goal': 900000.0,
#   'launched': '2012-08-15 21:20:10',
#   'pledged': 2229344.36,
#   'state': 'successful',
#   'backers': 44162,
#   'country': 'US',
#   'usd pledged': 2229344.36,
#   'usd_pledged_real': 2229344.36},
#  {'_id': 1618218442,
#   'name': "Pontruff's Pop Shop, Pizza, and Punk Rock",
#   'category': 'Restaurants',
#   'main_category': 'Food',
#   'currency': 'USD',
#   'deadline': '2014-09-26',
#   'goal': 500000.0,
#   'launched': '2014-07-28 09:05:22',
#   'pledged': 0.0,
#   'state': 'failed',
#   'backers': 0,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': 1402370273,
#   'name': 'The Good Fight of Faith',
#   'category': 'Family',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2015-11-19',
#   'goal': 1000000.0,
#   'launched': '2015-10-20 00:56:49',
#   'pledged': 0.0,
#   'state': 'failed',
#   'backers': 0,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': 410651072,
#   'name': 'Film Adaptation of "The Traveler"',
#   'category': 'Narrative Film',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2016-10-31',
#   'goal': 1000000.0,
#   'launched': '2016-10-01 19:42:33',
#   'pledged': 25.0,
#   'state': 'canceled',
#   'backers': 1,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 25.0},
#  {'_id': 670536219,
#   'name': 'Boulder Creek Brewery and Cafe Rebuild (Canceled)',
#   'category': 'Restaurants',
#   'main_category': 'Food',
#   'currency': 'USD',
#   'deadline': '2015-05-23',
#   'goal': 200000.0,
#   'launched': '2015-04-15 08:33:33',
#   'pledged': 12397.0,
#   'state': 'canceled',
#   'backers': 86,
#   'country': 'US',
#   'usd pledged': 12397.0,
#   'usd_pledged_real': 12397.0},
#  {'_id': 489938719,
#   'name': 'Uncommon Wealth',
#   'category': 'Narrative Film',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2013-11-24',
#   'goal': 250000.0,
#   'launched': '2013-09-25 18:39:09',
#   'pledged': 2110.0,
#   'state': 'failed',
#   'backers': 18,
#   'country': 'US',
#   'usd pledged': 2110.0,
#   'usd_pledged_real': 2110.0},
#  {'_id': 1730464042,
#   'name': 'Design the Starship Enterprise Science Research Mock Up',
#   'category': 'Technology',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2013-12-02',
#   'goal': 313550.0,
#   'launched': '2013-10-18 09:18:13',
#   'pledged': 31.0,
#   'state': 'failed',
#   'backers': 2,
#   'country': 'US',
#   'usd pledged': 31.0,
#   'usd_pledged_real': 31.0},
#  {'_id': 1517172285,
#   'name': 'Backyard Soccer Buddy / Football Mate (Overseas)',
#   'category': 'Gadgets',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2016-09-15',
#   'goal': 2000000.0,
#   'launched': '2016-07-20 18:37:09',
#   'pledged': 0.0,
#   'state': 'canceled',
#   'backers': 0,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': 469586156,
#   'name': 'Frickin! Fleasï¿½ Mobile Game',
#   'category': 'Mobile Games',
#   'main_category': 'Games',
#   'currency': 'USD',
#   'deadline': '2017-10-28',
#   'goal': 200000.0,
#   'launched': '2017-09-14 21:41:45',
#   'pledged': 353.0,
#   'state': 'failed',
#   'backers': 3,
#   'country': 'US',
#   'usd pledged': 250.0,
#   'usd_pledged_real': 353.0},
#  {'_id': 1523176093,
#   'name': '"anonymous (street meat)" (Canceled)',
#   'category': 'Film & Video',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2012-06-17',
#   'goal': 1000000.0,
#   'launched': '2012-05-18 08:18:34',
#   'pledged': 0.0,
#   'state': 'canceled',
#   'backers': 0,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': 1555404895,
#   'name': 'Better Days',
#   'category': 'Narrative Film',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2011-02-04',
#   'goal': 200000.0,
#   'launched': '2010-12-06 20:15:52',
#   'pledged': 50.0,
#   'state': 'failed',
#   'backers': 3,
#   'country': 'US',
#   'usd pledged': 50.0,
#   'usd_pledged_real': 50.0},
#  {'_id': 851609835,
#   'name': 'Akaneiro: Demon Hunters',
#   'category': 'Video Games',
#   'main_category': 'Games',
#   'currency': 'USD',
#   'deadline': '2013-02-03',
#   'goal': 200000.0,
#   'launched': '2013-01-04 00:27:43',
#   'pledged': 204680.93,
#   'state': 'successful',
#   'backers': 2681,
#   'country': 'US',
#   'usd pledged': 204680.93,
#   'usd_pledged_real': 204680.93},
#  {'_id': 934554143,
#   'name': 'Hello Space Boy!',
#   'category': 'Animation',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2016-07-31',
#   'goal': 2000000.0,
#   'launched': '2016-06-03 23:59:11',
#   'pledged': 0.0,
#   'state': 'failed',
#   'backers': 0,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': 1452500654,
#   'name': 'Interactive Breastfeeding Documentary',
#   'category': 'Documentary',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2011-09-20',
#   'goal': 210000.0,
#   'launched': '2011-08-02 15:54:48',
#   'pledged': 12058.3,
#   'state': 'failed',
#   'backers': 117,
#   'country': 'US',
#   'usd pledged': 12058.3,
#   'usd_pledged_real': 12058.3},
#  {'_id': 1783703627,
#   'name': 'Aquaponics system for supplying fresh organic food.',
#   'category': 'Farms',
#   'main_category': 'Food',
#   'currency': 'USD',
#   'deadline': '2016-06-05',
#   'goal': 8000000.0,
#   'launched': '2016-04-06 20:30:05',
#   'pledged': 21.0,
#   'state': 'failed',
#   'backers': 3,
#   'country': 'US',
#   'usd pledged': 21.0,
#   'usd_pledged_real': 21.0},
#  {'_id': 1028997654,
#   'name': 'After Reset RPG',
#   'category': 'Video Games',
#   'main_category': 'Games',
#   'currency': 'USD',
#   'deadline': '2013-12-11',
#   'goal': 900000.0,
#   'launched': '2013-11-11 10:41:59',
#   'pledged': 47939.0,
#   'state': 'failed',
#   'backers': 1362,
#   'country': 'US',
#   'usd pledged': 47939.0,
#   'usd_pledged_real': 47939.0},
#  {'_id': 731780695,
#   'name': 'SLAYING GIANTS #GOLIATH',
#   'category': 'Movie Theaters',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2016-08-20',
#   'goal': 350000.0,
#   'launched': '2016-07-21 03:42:14',
#   'pledged': 2508.0,
#   'state': 'failed',
#   'backers': 26,
#   'country': 'US',
#   'usd pledged': 175.0,
#   'usd_pledged_real': 2508.0},
#  {'_id': 776004598,
#   'name': 'Fan News',
#   'category': 'Journalism',
#   'main_category': 'Journalism',
#   'currency': 'USD',
#   'deadline': '2015-03-19',
#   'goal': 275000.0,
#   'launched': '2015-02-17 19:40:55',
#   'pledged': 10.0,
#   'state': 'failed',
#   'backers': 1,
#   'country': 'US',
#   'usd pledged': 10.0,
#   'usd_pledged_real': 10.0},
#  {'_id': 580110957,
#   'name': '*FLASHLIFE* Most Complete Emergency Survival Product Ever.',
#   'category': 'Hardware',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2016-11-05',
#   'goal': 350000.0,
#   'launched': '2016-09-21 20:21:50',
#   'pledged': 1865.0,
#   'state': 'failed',
#   'backers': 14,
#   'country': 'US',
#   'usd pledged': 1.0,
#   'usd_pledged_real': 1865.0},
#  {'_id': 644614031,
#   'name': "Iota: Never lose sight of what's important.",
#   'category': 'Technology',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2014-08-14',
#   'goal': 250000.0,
#   'launched': '2014-07-15 08:19:05',
#   'pledged': 282155.0,
#   'state': 'successful',
#   'backers': 1657,
#   'country': 'US',
#   'usd pledged': 282155.0,
#   'usd_pledged_real': 282155.0},
#  {'_id': 281465042,
#   'name': 'RHN - THE REAL HIP-HOP NETWORK TV CHANNEL  DOCUMENTARY',
#   'category': 'Film & Video',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2014-06-15',
#   'goal': 2000000.0,
#   'launched': '2014-05-01 20:01:10',
#   'pledged': 225.0,
#   'state': 'failed',
#   'backers': 3,
#   'country': 'US',
#   'usd pledged': 225.0,
#   'usd_pledged_real': 225.0},
#  {'_id': 1675510469,
#   'name': 'LAN Center',
#   'category': 'Technology',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2014-10-26',
#   'goal': 200000.0,
#   'launched': '2014-09-26 08:19:38',
#   'pledged': 2.0,
#   'state': 'failed',
#   'backers': 1,
#   'country': 'US',
#   'usd pledged': 2.0,
#   'usd_pledged_real': 2.0},
#  {'_id': 588787421,
#   'name': 'jfg76tukv u',
#   'category': 'Art',
#   'main_category': 'Art',
#   'currency': 'USD',
#   'deadline': '2015-12-31',
#   'goal': 250000.0,
#   'launched': '2015-11-19 16:47:03',
#   'pledged': 2.0,
#   'state': 'failed',
#   'backers': 1,
#   'country': 'US',
#   'usd pledged': 2.0,
#   'usd_pledged_real': 2.0},
#  {'_id': 742934297,
#   'name': 'Shaft in Asia Featured Film',
#   'category': 'Action',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2015-10-13',
#   'goal': 1000000.0,
#   'launched': '2015-08-14 22:56:40',
#   'pledged': 0.0,
#   'state': 'failed',
#   'backers': 0,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': 715019941,
#   'name': 'P.U.R.E. Gamers',
#   'category': 'Video Games',
#   'main_category': 'Games',
#   'currency': 'USD',
#   'deadline': '2015-10-04',
#   'goal': 500000.0,
#   'launched': '2015-08-06 22:22:00',
#   'pledged': 25.0,
#   'state': 'failed',
#   'backers': 1,
#   'country': 'US',
#   'usd pledged': 25.0,
#   'usd_pledged_real': 25.0},
#  {'_id': 818541249,
#   'name': 'The Hawaiian Girl Art Studio (Canceled)',
#   'category': 'Digital Art',
#   'main_category': 'Art',
#   'currency': 'USD',
#   'deadline': '2016-03-24',
#   'goal': 1100000.0,
#   'launched': '2016-01-26 05:48:05',
#   'pledged': 0.0,
#   'state': 'canceled',
#   'backers': 0,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': 1312071514,
#   'name': 'The Rock Bar - Mobile Bar/Event Platform',
#   'category': 'Events',
#   'main_category': 'Food',
#   'currency': 'USD',
#   'deadline': '2015-05-24',
#   'goal': 200000.0,
#   'launched': '2015-04-09 01:28:16',
#   'pledged': 0.0,
#   'state': 'failed',
#   'backers': 0,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': 206228383,
#   'name': 'The Wager',
#   'category': 'Action',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2015-04-12',
#   'goal': 200000.0,
#   'launched': '2015-02-11 20:02:00',
#   'pledged': 10.0,
#   'state': 'failed',
#   'backers': 1,
#   'country': 'US',
#   'usd pledged': 10.0,
#   'usd_pledged_real': 10.0},
#  {'_id': 466162671,
#   'name': 'xFaire: A TV Device. Watch Any Content, Anytime & Anywhere',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'currency': 'USD',
#   'deadline': '2016-07-21',
#   'goal': 200000.0,
#   'launched': '2016-06-06 20:36:49',
#   'pledged': 3523.0,
#   'state': 'canceled',
#   'backers': 29,
#   'country': 'US',
#   'usd pledged': 3227.0,
#   'usd_pledged_real': 3523.0},
#  {'_id': 1051776765,
#   'name': 'Independent Broadcasting Company',
#   'category': 'Television',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2017-05-31',
#   'goal': 700000.0,
#   'launched': '2017-04-01 02:34:51',
#   'pledged': 56.0,
#   'state': 'canceled',
#   'backers': 3,
#   'country': 'US',
#   'usd pledged': 56.0,
#   'usd_pledged_real': 56.0},
#  {'_id': 595664945,
#   'name': 'Forbidden Woods (Canceled)',
#   'category': 'Film & Video',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2012-08-18',
#   'goal': 2300000.0,
#   'launched': '2012-07-19 21:12:51',
#   'pledged': 0.0,
#   'state': 'canceled',
#   'backers': 0,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': 1348230166,
#   'name': "Max and Rex's Adventure",
#   'category': 'Video Games',
#   'main_category': 'Games',
#   'currency': 'USD',
#   'deadline': '2012-05-12',
#   'goal': 200000.0,
#   'launched': '2012-03-28 04:06:56',
#   'pledged': 4286.0,
#   'state': 'failed',
#   'backers': 21,
#   'country': 'US',
#   'usd pledged': 4286.0,
#   'usd_pledged_real': 4286.0},
#  {'_id': 788197692,
#   'name': 'The Guilt Free Life',
#   'category': 'Restaurants',
#   'main_category': 'Food',
#   'currency': 'USD',
#   'deadline': '2014-08-27',
#   'goal': 250000.0,
#   'launched': '2014-06-28 22:05:03',
#   'pledged': 20.0,
#   'state': 'failed',
#   'backers': 3,
#   'country': 'US',
#   'usd pledged': 20.0,
#   'usd_pledged_real': 20.0},
#  {'_id': 1254965074,
#   'name': 'Mayacama Chocolate-Bean-to-Bar Craft Chocolate, Napa,Ca',
#   'category': 'Small Batch',
#   'main_category': 'Food',
#   'currency': 'USD',
#   'deadline': '2015-04-19',
#   'goal': 780000.0,
#   'launched': '2015-02-18 17:23:50',
#   'pledged': 267.0,
#   'state': 'failed',
#   'backers': 6,
#   'country': 'US',
#   'usd pledged': 267.0,
#   'usd_pledged_real': 267.0},
#  {'_id': 178418310,
#   'name': 'Puzzle Camp',
#   'category': 'Games',
#   'main_category': 'Games',
#   'currency': 'USD',
#   'deadline': '2014-06-18',
#   'goal': 750000.0,
#   'launched': '2014-05-19 03:56:46',
#   'pledged': 35.0,
#   'state': 'failed',
#   'backers': 1,
#   'country': 'US',
#   'usd pledged': 35.0,
#   'usd_pledged_real': 35.0},
#  {'_id': 1473597203,
#   'name': 'Vehroot Shelf | Use Your Phone or Tablet as Your Car Stereo',
#   'category': 'Sound',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2018-01-11',
#   'goal': 500000.0,
#   'launched': '2017-12-12 18:46:26',
#   'pledged': 5651.0,
#   'state': 'live',
#   'backers': 14,
#   'country': 'US',
#   'usd pledged': 1248.0,
#   'usd_pledged_real': 5651.0},
#  {'_id': 715203303,
#   'name': "THE YING YANG MURDER MYSTERY'S (Canceled)",
#   'category': 'Webseries',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2014-12-31',
#   'goal': 900000.0,
#   'launched': '2014-12-01 23:50:57',
#   'pledged': 0.0,
#   'state': 'canceled',
#   'backers': 0,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': 374403417,
#   'name': 'Montgomery Al Concert 5FDP and VOLBEAT',
#   'category': 'Rock',
#   'main_category': 'Music',
#   'currency': 'USD',
#   'deadline': '2014-07-24',
#   'goal': 1040000.0,
#   'launched': '2014-06-24 02:58:50',
#   'pledged': 0.0,
#   'state': 'failed',
#   'backers': 0,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': 1935538858,
#   'name': 'Wall Scaler',
#   'category': 'Flight',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2017-04-17',
#   'goal': 1000000.0,
#   'launched': '2017-03-03 21:30:39',
#   'pledged': 1.0,
#   'state': 'suspended',
#   'backers': 1,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 1.0},
#  {'_id': 1926637288,
#   'name': 'Historic B&B with an in-house French Bakery in Memphis, TN',
#   'category': 'Food',
#   'main_category': 'Food',
#   'currency': 'USD',
#   'deadline': '2016-07-23',
#   'goal': 250000.0,
#   'launched': '2016-06-23 01:13:20',
#   'pledged': 10100.0,
#   'state': 'failed',
#   'backers': 2,
#   'country': 'US',
#   'usd pledged': 10100.0,
#   'usd_pledged_real': 10100.0},
#  {'_id': 781443672,
#   'name': 'Eternal Fate',
#   'category': 'Video Games',
#   'main_category': 'Games',
#   'currency': 'USD',
#   'deadline': '2012-09-01',
#   'goal': 200000.0,
#   'launched': '2012-08-02 07:36:08',
#   'pledged': 12914.0,
#   'state': 'failed',
#   'backers': 234,
#   'country': 'US',
#   'usd pledged': 12914.0,
#   'usd_pledged_real': 12914.0},
#  {'_id': 1715597415,
#   'name': 'Angelz Landing the Movie',
#   'category': 'Film & Video',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2014-02-17',
#   'goal': 1200000.0,
#   'launched': '2014-01-13 19:08:09',
#   'pledged': 356.0,
#   'state': 'failed',
#   'backers': 5,
#   'country': 'US',
#   'usd pledged': 356.0,
#   'usd_pledged_real': 356.0},
#  {'_id': 779336498,
#   'name': 'Morrison Land',
#   'category': 'Movie Theaters',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2014-07-27',
#   'goal': 250000.0,
#   'launched': '2014-05-28 19:42:35',
#   'pledged': 10.0,
#   'state': 'failed',
#   'backers': 6,
#   'country': 'US',
#   'usd pledged': 10.0,
#   'usd_pledged_real': 10.0},
#  {'_id': 1934580784,
#   'name': 'Triple Espresso Goes to The Big Apple',
#   'category': 'Theater',
#   'main_category': 'Theater',
#   'currency': 'USD',
#   'deadline': '2013-03-16',
#   'goal': 300000.0,
#   'launched': '2013-02-09 21:01:57',
#   'pledged': 27581.0,
#   'state': 'failed',
#   'backers': 116,
#   'country': 'US',
#   'usd pledged': 27581.0,
#   'usd_pledged_real': 27581.0},
#  {'_id': 107644423,
#   'name': 'Meetupgolf - Everything Golf, Everything Social',
#   'category': 'Technology',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2016-09-21',
#   'goal': 200000.0,
#   'launched': '2016-08-22 18:44:37',
#   'pledged': 360.0,
#   'state': 'canceled',
#   'backers': 8,
#   'country': 'US',
#   'usd pledged': 25.0,
#   'usd_pledged_real': 360.0},
#  {'_id': 1081925218,
#   'name': 'GunDetect - alerts you when it sees a gun',
#   'category': 'Technology',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2015-08-20',
#   'goal': 200000.0,
#   'launched': '2015-07-15 01:03:04',
#   'pledged': 43718.0,
#   'state': 'failed',
#   'backers': 10,
#   'country': 'US',
#   'usd pledged': 43718.0,
#   'usd_pledged_real': 43718.0},
#  {'_id': 1596314651,
#   'name': 'Take And Seek the Movie',
#   'category': 'Film & Video',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2013-09-16',
#   'goal': 250000.0,
#   'launched': '2013-08-16 04:59:36',
#   'pledged': 0.0,
#   'state': 'failed',
#   'backers': 0,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': 1834526569,
#   'name': 'Unsung Story: Tale of the Guardians',
#   'category': 'Video Games',
#   'main_category': 'Games',
#   'currency': 'USD',
#   'deadline': '2014-02-15',
#   'goal': 600000.0,
#   'launched': '2014-01-14 19:03:30',
#   'pledged': 660126.51,
#   'state': 'successful',
#   'backers': 15824,
#   'country': 'US',
#   'usd pledged': 660126.51,
#   'usd_pledged_real': 660126.51},
#  {'_id': 2007557271,
#   'name': 'Harishwar Center for Arts, Spirituality & Sustainability',
#   'category': 'Architecture',
#   'main_category': 'Design',
#   'currency': 'USD',
#   'deadline': '2016-02-03',
#   'goal': 1800000.0,
#   'launched': '2016-01-04 20:26:57',
#   'pledged': 614.0,
#   'state': 'failed',
#   'backers': 14,
#   'country': 'US',
#   'usd pledged': 614.0,
#   'usd_pledged_real': 614.0},
#  {'_id': 695668947,
#   'name': "The Cancer Patient's Film Project",
#   'category': 'Narrative Film',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2013-08-17',
#   'goal': 1500000.0,
#   'launched': '2013-07-12 02:38:19',
#   'pledged': 275.0,
#   'state': 'failed',
#   'backers': 2,
#   'country': 'US',
#   'usd pledged': 275.0,
#   'usd_pledged_real': 275.0},
#  {'_id': 832080779,
#   'name': "Small Change: Kids' Financial Life Skills",
#   'category': 'Software',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2014-08-11',
#   'goal': 250000.0,
#   'launched': '2014-07-17 15:54:12',
#   'pledged': 3536.0,
#   'state': 'failed',
#   'backers': 39,
#   'country': 'US',
#   'usd pledged': 3536.0,
#   'usd_pledged_real': 3536.0},
#  {'_id': 1656648684,
#   'name': 'Save the Williamsburg',
#   'category': 'Public Art',
#   'main_category': 'Art',
#   'currency': 'USD',
#   'deadline': '2015-10-27',
#   'goal': 40000000.0,
#   'launched': '2015-09-27 15:08:05',
#   'pledged': 21700.0,
#   'state': 'failed',
#   'backers': 15,
#   'country': 'US',
#   'usd pledged': 21700.0,
#   'usd_pledged_real': 21700.0},
#  {'_id': 256448010,
#   'name': 'Nephilim, Nazis and the New World Order',
#   'category': 'Documentary',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2015-07-12',
#   'goal': 500000.0,
#   'launched': '2015-05-13 03:45:32',
#   'pledged': 0.0,
#   'state': 'failed',
#   'backers': 0,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': 978588144,
#   'name': 'War At Home',
#   'category': 'Drama',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2015-11-28',
#   'goal': 340000.0,
#   'launched': '2015-10-29 16:00:52',
#   'pledged': 19328.0,
#   'state': 'failed',
#   'backers': 273,
#   'country': 'US',
#   'usd pledged': 19328.0,
#   'usd_pledged_real': 19328.0},
#  {'_id': 208391519,
#   'name': 'North East',
#   'category': 'Drama',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2017-07-23',
#   'goal': 250000.0,
#   'launched': '2017-05-24 00:17:26',
#   'pledged': 2.0,
#   'state': 'failed',
#   'backers': 2,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 2.0},
#  {'_id': 1789241689,
#   'name': 'The Great Pyramid, Project USA',
#   'category': 'Technology',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2014-08-01',
#   'goal': 300000.0,
#   'launched': '2014-06-02 15:53:58',
#   'pledged': 35.0,
#   'state': 'failed',
#   'backers': 2,
#   'country': 'US',
#   'usd pledged': 35.0,
#   'usd_pledged_real': 35.0},
#  {'_id': 2126842880,
#   'name': 'Time travel app',
#   'category': 'Apps',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2017-10-09',
#   'goal': 375000.0,
#   'launched': '2017-09-12 21:06:34',
#   'pledged': 135.0,
#   'state': 'failed',
#   'backers': 3,
#   'country': 'US',
#   'usd pledged': 10.0,
#   'usd_pledged_real': 135.0},
#  {'_id': 1046230768,
#   'name': 'Honolulu Haze (Canceled)',
#   'category': 'Narrative Film',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2013-07-07',
#   'goal': 500000.0,
#   'launched': '2013-05-08 18:00:16',
#   'pledged': 70.0,
#   'state': 'canceled',
#   'backers': 2,
#   'country': 'US',
#   'usd pledged': 70.0,
#   'usd_pledged_real': 70.0},
#  {'_id': 2135350794,
#   'name': 'Motor Sports Mailboxes',
#   'category': 'Crafts',
#   'main_category': 'Crafts',
#   'currency': 'USD',
#   'deadline': '2015-01-18',
#   'goal': 600000.0,
#   'launched': '2014-11-19 20:20:55',
#   'pledged': 200.0,
#   'state': 'failed',
#   'backers': 1,
#   'country': 'US',
#   'usd pledged': 200.0,
#   'usd_pledged_real': 200.0},
#  {'_id': 381953552,
#   'name': 'Patented MoveNetic Lock - New Post 9-11 Locking Method',
#   'category': 'Hardware',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2014-10-08',
#   'goal': 350000.0,
#   'launched': '2014-09-03 01:33:36',
#   'pledged': 60.0,
#   'state': 'canceled',
#   'backers': 3,
#   'country': 'US',
#   'usd pledged': 60.0,
#   'usd_pledged_real': 60.0},
#  {'_id': 2108775311,
#   'name': 'Where Is the Love? (A Dedication to Love) (Canceled)',
#   'category': 'Film & Video',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2012-07-12',
#   'goal': 200000.0,
#   'launched': '2012-06-12 00:35:18',
#   'pledged': 5.0,
#   'state': 'canceled',
#   'backers': 1,
#   'country': 'US',
#   'usd pledged': 5.0,
#   'usd_pledged_real': 5.0},
#  {'_id': 1393231622,
#   'name': 'Love Over A Million Years',
#   'category': 'Movie Theaters',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2016-02-10',
#   'goal': 200000.0,
#   'launched': '2015-12-12 04:53:07',
#   'pledged': 0.0,
#   'state': 'failed',
#   'backers': 0,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': 749406436,
#   'name': 'Hoverboard: The Next Evolution in Personal Electric Mobility',
#   'category': 'Hardware',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2015-10-22',
#   'goal': 500000.0,
#   'launched': '2015-09-17 16:39:03',
#   'pledged': 257275.0,
#   'state': 'failed',
#   'backers': 239,
#   'country': 'US',
#   'usd pledged': 257275.0,
#   'usd_pledged_real': 257275.0},
#  {'_id': 1812682282,
#   'name': 'Make A South African Feature Film! (Canceled)',
#   'category': 'Narrative Film',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2011-12-31',
#   'goal': 2500000.0,
#   'launched': '2011-12-05 17:22:45',
#   'pledged': 0.0,
#   'state': 'canceled',
#   'backers': 0,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': 892520897,
#   'name': 'Feature-Length Movie: Secret of the Missing Grave',
#   'category': 'Film & Video',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2013-07-02',
#   'goal': 10000000.0,
#   'launched': '2013-05-03 23:15:16',
#   'pledged': 11975.0,
#   'state': 'failed',
#   'backers': 24,
#   'country': 'US',
#   'usd pledged': 11975.0,
#   'usd_pledged_real': 11975.0},
#  {'_id': 396599619,
#   'name': "Hey Chicago  It's all about you!",
#   'category': 'Design',
#   'main_category': 'Design',
#   'currency': 'USD',
#   'deadline': '2015-10-01',
#   'goal': 380000.0,
#   'launched': '2015-08-17 09:43:37',
#   'pledged': 950.0,
#   'state': 'failed',
#   'backers': 7,
#   'country': 'US',
#   'usd pledged': 950.0,
#   'usd_pledged_real': 950.0},
#  {'_id': 2028395602,
#   'name': 'All Points Bulletin (APB): Vendetta',
#   'category': 'Video Games',
#   'main_category': 'Games',
#   'currency': 'USD',
#   'deadline': '2013-05-01',
#   'goal': 300000.0,
#   'launched': '2013-03-27 04:05:39',
#   'pledged': 27614.0,
#   'state': 'failed',
#   'backers': 161,
#   'country': 'US',
#   'usd pledged': 27614.0,
#   'usd_pledged_real': 27614.0},
#  {'_id': 233857280,
#   'name': 'As Cine On TV',
#   'category': 'Translations',
#   'main_category': 'Publishing',
#   'currency': 'USD',
#   'deadline': '2017-04-29',
#   'goal': 2000000.0,
#   'launched': '2017-03-30 05:36:14',
#   'pledged': 192.0,
#   'state': 'failed',
#   'backers': 4,
#   'country': 'US',
#   'usd pledged': 50.0,
#   'usd_pledged_real': 192.0},
#  {'_id': 1489384109,
#   'name': 'The Hendrix Keg - Carbonated, Fresh, Craft Beer on Tap',
#   'category': 'Technology',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2017-10-15',
#   'goal': 300000.0,
#   'launched': '2017-08-16 15:47:26',
#   'pledged': 48307.0,
#   'state': 'canceled',
#   'backers': 325,
#   'country': 'US',
#   'usd pledged': 9302.0,
#   'usd_pledged_real': 48307.0},
#  {'_id': 898479897,
#   'name': 'Supporting Disaster Relief through the Power of Music',
#   'category': 'Classical Music',
#   'main_category': 'Music',
#   'currency': 'USD',
#   'deadline': '2017-03-01',
#   'goal': 200000.0,
#   'launched': '2017-01-30 05:20:32',
#   'pledged': 560.0,
#   'state': 'canceled',
#   'backers': 5,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 560.0},
#  {'_id': 1968365932,
#   'name': "#TINYHUMANSGETTIN'FRESH! Help a Veteran's Wife's Company!",
#   'category': 'Food',
#   'main_category': 'Food',
#   'currency': 'USD',
#   'deadline': '2014-05-04',
#   'goal': 200000.0,
#   'launched': '2014-04-04 20:25:37',
#   'pledged': 106.0,
#   'state': 'canceled',
#   'backers': 4,
#   'country': 'US',
#   'usd pledged': 106.0,
#   'usd_pledged_real': 106.0},
#  {'_id': 1489393006,
#   'name': 'On The Wings Of A Miracle - An Animated Family Film',
#   'category': 'Animation',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2012-10-23',
#   'goal': 200000.0,
#   'launched': '2012-09-21 16:30:40',
#   'pledged': 4135.0,
#   'state': 'failed',
#   'backers': 21,
# ...
#   'pledged': 0.0,
#   'state': 'failed',
#   'backers': 0,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': 993969686,
#   'name': 'Albert Einstein Museum',
#   'category': 'Technology',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2014-12-20',
#   'goal': 50000000.0,
#   'launched': '2014-10-23 01:46:17',
#   'pledged': 240.0,
#   'state': 'failed',
#   'backers': 8,
#   'country': 'US',
#   'usd pledged': 240.0,
#   'usd_pledged_real': 240.0},
#  {'_id': 1410449094,
#   'name': 'NEW MENS COLOGNE!',
#   'category': 'Fashion',
#   'main_category': 'Fashion',
#   'currency': 'USD',
#   'deadline': '2015-05-22',
#   'goal': 400000.0,
#   'launched': '2015-03-23 18:25:27',
#   'pledged': 0.0,
#   'state': 'failed',
#   'backers': 0,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': 1479851539,
#   'name': 'SelfiePICTEE',
#   'category': 'Wearables',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2015-07-02',
#   'goal': 500000.0,
#   'launched': '2015-05-19 11:14:26',
#   'pledged': 456.0,
#   'state': 'failed',
#   'backers': 8,
#   'country': 'US',
#   'usd pledged': 456.0,
#   'usd_pledged_real': 456.0},
#  {'_id': 1714131977,
#   'name': 'China Meet World',
#   'category': 'Television',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2014-11-06',
#   'goal': 2646000.0,
#   'launched': '2014-10-07 01:31:23',
#   'pledged': 0.0,
#   'state': 'failed',
#   'backers': 0,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': 1185151992,
#   'name': 'Forbidden Doors - The Movie',
#   'category': 'Thrillers',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2014-11-17',
#   'goal': 400000.0,
#   'launched': '2014-10-16 03:33:07',
#   'pledged': 10772.0,
#   'state': 'failed',
#   'backers': 82,
#   'country': 'US',
#   'usd pledged': 10772.0,
#   'usd_pledged_real': 10772.0},
#  {'_id': 1544030819,
#   'name': "PrivacyAtlas - It's Your Life - Make Sure It's Protected!",
#   'category': 'Web',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2014-07-08',
#   'goal': 200000.0,
#   'launched': '2014-06-23 18:44:00',
#   'pledged': 56.0,
#   'state': 'failed',
#   'backers': 3,
#   'country': 'US',
#   'usd pledged': 56.0,
#   'usd_pledged_real': 56.0},
#  {'_id': 1643578684,
#   'name': 'Thumper (Canceled)',
#   'category': 'Narrative Film',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2013-06-28',
#   'goal': 500000.0,
#   'launched': '2013-05-29 14:58:20',
#   'pledged': 6961.0,
#   'state': 'canceled',
#   'backers': 35,
#   'country': 'US',
#   'usd pledged': 6961.0,
#   'usd_pledged_real': 6961.0},
#  {'_id': 422405466,
#   'name': 'ME+ "Electricfying Our World"',
#   'category': 'Technology',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2014-10-20',
#   'goal': 250000.0,
#   'launched': '2014-09-10 23:31:44',
#   'pledged': 151.0,
#   'state': 'failed',
#   'backers': 3,
#   'country': 'US',
#   'usd pledged': 151.0,
#   'usd_pledged_real': 151.0},
#  {'_id': 1300624545,
#   'name': 'www.GuysDoLunch.com',
#   'category': 'Software',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2015-03-13',
#   'goal': 500000.0,
#   'launched': '2015-02-11 20:55:11',
#   'pledged': 25.0,
#   'state': 'failed',
#   'backers': 1,
#   'country': 'US',
#   'usd pledged': 25.0,
#   'usd_pledged_real': 25.0},
#  {'_id': 1369023580,
#   'name': 'PetWashSPA: The first home SPA system for your pets.',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'currency': 'USD',
#   'deadline': '2015-04-12',
#   'goal': 220000.0,
#   'launched': '2015-02-26 02:53:07',
#   'pledged': 1198.0,
#   'state': 'canceled',
#   'backers': 14,
#   'country': 'US',
#   'usd pledged': 1198.0,
#   'usd_pledged_real': 1198.0},
#  {'_id': 222456629,
#   'name': 'imealhost.com',
#   'category': 'Food',
#   'main_category': 'Food',
#   'currency': 'USD',
#   'deadline': '2015-11-19',
#   'goal': 250000.0,
#   'launched': '2015-10-21 01:08:06',
#   'pledged': 0.0,
#   'state': 'failed',
#   'backers': 0,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': 553403140,
#   'name': 'FOCUS ON THE OCEAN',
#   'category': 'Sculpture',
#   'main_category': 'Art',
#   'currency': 'USD',
#   'deadline': '2012-08-26',
#   'goal': 350000.0,
#   'launched': '2012-07-27 02:22:39',
#   'pledged': 1226.0,
#   'state': 'failed',
#   'backers': 4,
#   'country': 'US',
#   'usd pledged': 1226.0,
#   'usd_pledged_real': 1226.0},
#  {'_id': 1141827345,
#   'name': 'Ground Branch',
#   'category': 'Video Games',
#   'main_category': 'Games',
#   'currency': 'USD',
#   'deadline': '2012-07-07',
#   'goal': 425000.0,
#   'launched': '2012-06-02 00:56:28',
#   'pledged': 111111.54,
#   'state': 'failed',
#   'backers': 1897,
#   'country': 'US',
#   'usd pledged': 111111.54,
#   'usd_pledged_real': 111111.54},
#  {'_id': 590993419,
#   'name': 'Leviathans Online: Monsters In The Sky (Canceled)',
#   'category': 'Video Games',
#   'main_category': 'Games',
#   'currency': 'USD',
#   'deadline': '2013-01-17',
#   'goal': 300000.0,
#   'launched': '2012-12-03 17:23:07',
#   'pledged': 10556.03,
#   'state': 'canceled',
#   'backers': 213,
#   'country': 'US',
#   'usd pledged': 10556.03,
#   'usd_pledged_real': 10556.03},
#  {'_id': 133310028,
#   'name': "William Malone's THALLIUM'S BOX",
#   'category': 'Horror',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2015-06-01',
#   'goal': 350000.0,
#   'launched': '2015-05-02 23:13:40',
#   'pledged': 19410.0,
#   'state': 'failed',
#   'backers': 71,
#   'country': 'US',
#   'usd pledged': 19410.0,
#   'usd_pledged_real': 19410.0},
#  {'_id': 962949560,
#   'name': '"PG" Reanimated Cartoons Tha Movie',
#   'category': 'Animation',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2015-04-11',
#   'goal': 100000000.0,
#   'launched': '2015-02-10 23:49:30',
#   'pledged': 0.0,
#   'state': 'failed',
#   'backers': 0,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': 870909178,
#   'name': 'SportsBucketList.net',
#   'category': 'Web',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2015-03-13',
#   'goal': 250000.0,
#   'launched': '2015-02-11 20:51:31',
#   'pledged': 0.0,
#   'state': 'failed',
#   'backers': 0,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': 1139392193,
#   'name': 'Bridging the Minooka area to "Back in the Day"',
#   'category': 'Restaurants',
#   'main_category': 'Food',
#   'currency': 'USD',
#   'deadline': '2014-10-30',
#   'goal': 200000.0,
#   'launched': '2014-09-15 19:19:56',
#   'pledged': 1.0,
#   'state': 'failed',
#   'backers': 1,
#   'country': 'US',
#   'usd pledged': 1.0,
#   'usd_pledged_real': 1.0},
#  {'_id': 473043717,
#   'name': 'DMG Recording Studio',
#   'category': 'Music',
#   'main_category': 'Music',
#   'currency': 'USD',
#   'deadline': '2015-02-26',
#   'goal': 250000.0,
#   'launched': '2015-01-27 02:28:55',
#   'pledged': 0.0,
#   'state': 'failed',
#   'backers': 0,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': 1221279169,
#   'name': 'ProTap: Draft Beer, Wine, and Cold Beverage Dispenser',
#   'category': 'Drinks',
#   'main_category': 'Food',
#   'currency': 'USD',
#   'deadline': '2017-04-20',
#   'goal': 350000.0,
#   'launched': '2017-03-21 19:25:56',
#   'pledged': 7188.0,
#   'state': 'failed',
#   'backers': 21,
#   'country': 'US',
#   'usd pledged': 3565.0,
#   'usd_pledged_real': 7188.0},
#  {'_id': 438065651,
#   'name': 'The Bobcat Exterior Rodent Bait Station',
#   'category': 'Hardware',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2015-04-29',
#   'goal': 225000.0,
#   'launched': '2015-03-30 19:43:04',
#   'pledged': 179.0,
#   'state': 'failed',
#   'backers': 3,
#   'country': 'US',
#   'usd pledged': 179.0,
#   'usd_pledged_real': 179.0},
#  {'_id': 1714819094,
#   'name': 'Edesia: Fresh, homemade and delicious Italian food!',
#   'category': 'Restaurants',
#   'main_category': 'Food',
#   'currency': 'USD',
#   'deadline': '2014-08-20',
#   'goal': 500000.0,
#   'launched': '2014-07-21 17:45:03',
#   'pledged': 0.0,
#   'state': 'failed',
#   'backers': 0,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': 518050281,
#   'name': 'Your Way Game Board',
#   'category': 'Tabletop Games',
#   'main_category': 'Games',
#   'currency': 'USD',
#   'deadline': '2014-09-04',
#   'goal': 250000.0,
#   'launched': '2014-08-05 23:13:00',
#   'pledged': 0.0,
#   'state': 'failed',
#   'backers': 0,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': 1361206718,
#   'name': 'Endorsit: Reviewed by You... Endorsed by the Community',
#   'category': 'Web',
#   'main_category': 'Journalism',
#   'currency': 'USD',
#   'deadline': '2016-04-27',
#   'goal': 200000.0,
#   'launched': '2016-02-27 17:20:57',
#   'pledged': 137.0,
#   'state': 'failed',
#   'backers': 5,
#   'country': 'US',
#   'usd pledged': 137.0,
#   'usd_pledged_real': 137.0},
#  {'_id': 577847537,
#   'name': 'Bobby Rush: Live at the Great Wall of China',
#   'category': 'Documentary',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2013-04-15',
#   'goal': 200000.0,
#   'launched': '2013-03-14 19:25:26',
#   'pledged': 0.0,
#   'state': 'failed',
#   'backers': 0,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': 535694516,
#   'name': 'A Gangster Movie called,  GET LOUIE',
#   'category': 'Action',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2015-08-06',
#   'goal': 2000000.0,
#   'launched': '2015-06-07 17:22:55',
#   'pledged': 20.0,
#   'state': 'failed',
#   'backers': 1,
#   'country': 'US',
#   'usd pledged': 20.0,
#   'usd_pledged_real': 20.0},
#  {'_id': 1296255094,
#   'name': 'Stark Drive Electric Bike',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'currency': 'USD',
#   'deadline': '2016-12-31',
#   'goal': 250000.0,
#   'launched': '2016-11-01 11:55:45',
#   'pledged': 17854.0,
#   'state': 'canceled',
#   'backers': 22,
#   'country': 'US',
#   'usd pledged': 2622.0,
#   'usd_pledged_real': 17854.0},
#  {'_id': 1823366426,
#   'name': 'Atheism is Winning! (Canceled)',
#   'category': 'Fashion',
#   'main_category': 'Fashion',
#   'currency': 'USD',
#   'deadline': '2014-11-29',
#   'goal': 500000.0,
#   'launched': '2014-09-30 20:05:09',
#   'pledged': 0.0,
#   'state': 'canceled',
#   'backers': 0,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': 1039730493,
#   'name': 'Metroryde technology for riders and independent operators',
#   'category': 'Apps',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2016-12-21',
#   'goal': 200000.0,
#   'launched': '2016-11-08 05:58:12',
#   'pledged': 155.0,
#   'state': 'canceled',
#   'backers': 6,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 155.0},
#  {'_id': 1631352976,
#   'name': 'GRANNY, The Movie (starring Jamie Kennedy) (Canceled)',
#   'category': 'Narrative Film',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2013-10-07',
#   'goal': 500000.0,
#   'launched': '2013-09-07 01:00:19',
#   'pledged': 601.0,
#   'state': 'canceled',
#   'backers': 20,
#   'country': 'US',
#   'usd pledged': 601.0,
#   'usd_pledged_real': 601.0},
#  {'_id': 1881943558,
#   'name': 'Wining and Dining on the Yacht',
#   'category': 'Restaurants',
#   'main_category': 'Food',
#   'currency': 'USD',
#   'deadline': '2015-09-22',
#   'goal': 250000.0,
#   'launched': '2015-08-23 22:02:49',
#   'pledged': 0.0,
#   'state': 'failed',
#   'backers': 0,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': 2045524340,
#   'name': 'Saving Trayvon',
#   'category': 'Documentary',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2012-05-11',
#   'goal': 200000.0,
#   'launched': '2012-04-11 04:58:14',
#   'pledged': 0.0,
#   'state': 'failed',
#   'backers': 0,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': 557482111,
#   'name': 'Trendy - Style Simplified',
#   'category': 'Apps',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2016-09-23',
#   'goal': 200000.0,
#   'launched': '2016-08-24 18:19:09',
#   'pledged': 15.0,
#   'state': 'canceled',
#   'backers': 1,
#   'country': 'US',
#   'usd pledged': 15.0,
#   'usd_pledged_real': 15.0},
#  {'_id': 1390150792,
#   'name': 'The Citizen Body Camera with Tamper-proof Online Backup',
#   'category': 'Wearables',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2015-06-26',
#   'goal': 250000.0,
#   'launched': '2015-04-27 10:54:06',
#   'pledged': 167.0,
#   'state': 'failed',
#   'backers': 8,
#   'country': 'US',
#   'usd pledged': 167.0,
#   'usd_pledged_real': 167.0},
#  {'_id': 768907657,
#   'name': 'The Good Guys (Blood over Everything)',
#   'category': 'Video Games',
#   'main_category': 'Games',
#   'currency': 'USD',
#   'deadline': '2013-08-25',
#   'goal': 250000.0,
#   'launched': '2013-06-26 00:00:05',
#   'pledged': 202.06,
#   'state': 'failed',
#   'backers': 4,
#   'country': 'US',
#   'usd pledged': 202.06,
#   'usd_pledged_real': 202.06},
#  {'_id': 1242311139,
#   'name': 'BAD PLANET',
#   'category': 'Video Games',
#   'main_category': 'Games',
#   'currency': 'USD',
#   'deadline': '2012-08-16',
#   'goal': 575000.0,
#   'launched': '2012-07-12 15:02:21',
#   'pledged': 45415.91,
#   'state': 'failed',
#   'backers': 638,
#   'country': 'US',
#   'usd pledged': 45415.91,
#   'usd_pledged_real': 45415.91},
#  {'_id': 715537620,
#   'name': 'Winthrop and Chester (Canceled)',
#   'category': 'Animation',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2013-06-29',
#   'goal': 200000.0,
#   'launched': '2013-05-30 22:43:01',
#   'pledged': 2930.0,
#   'state': 'canceled',
#   'backers': 62,
#   'country': 'US',
#   'usd pledged': 2930.0,
#   'usd_pledged_real': 2930.0},
#  {'_id': 1863870779,
#   'name': 'BodyCopter',
#   'category': 'Flight',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2017-12-10',
#   'goal': 2000000.0,
#   'launched': '2017-11-10 00:56:36',
#   'pledged': 240.0,
#   'state': 'failed',
#   'backers': 5,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 240.0},
#  {'_id': 1070802237,
#   'name': 'XCenter College Of Art, Music & Design',
#   'category': 'Civic Design',
#   'main_category': 'Design',
#   'currency': 'USD',
#   'deadline': '2017-01-30',
#   'goal': 10000000.0,
#   'launched': '2016-12-01 03:27:13',
#   'pledged': 0.0,
#   'state': 'failed',
#   'backers': 0,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': 964395491,
#   'name': 'Rainbow Reef : a sit-com starring Ed Asner & Danilo DiJulio',
#   'category': 'Film & Video',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2014-04-18',
#   'goal': 400000.0,
#   'launched': '2014-03-17 23:36:45',
#   'pledged': 565.0,
#   'state': 'canceled',
#   'backers': 6,
#   'country': 'US',
#   'usd pledged': 565.0,
#   'usd_pledged_real': 565.0},
#  {'_id': 1528846653,
#   'name': 'Hotbox Hooka',
#   'category': 'Restaurants',
#   'main_category': 'Food',
#   'currency': 'USD',
#   'deadline': '2015-08-03',
#   'goal': 450000.0,
#   'launched': '2015-07-04 21:26:50',
#   'pledged': 0.0,
#   'state': 'failed',
#   'backers': 0,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': 838492504,
#   'name': 'Save Black Earth Meats',
#   'category': 'Food',
#   'main_category': 'Food',
#   'currency': 'USD',
#   'deadline': '2014-12-04',
#   'goal': 225000.0,
#   'launched': '2014-10-20 19:04:06',
#   'pledged': 91116.0,
#   'state': 'failed',
#   'backers': 991,
#   'country': 'US',
#   'usd pledged': 91116.0,
#   'usd_pledged_real': 91116.0},
#  {'_id': 1535995528,
#   'name': 'Spokios.tv',
#   'category': 'Technology',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2015-03-16',
#   'goal': 1500000.0,
#   'launched': '2015-01-16 23:25:39',
#   'pledged': 0.0,
#   'state': 'failed',
#   'backers': 0,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': 1219018810,
#   'name': 'Apparatus for harnessing solar energy Patent US 8,770,186 B2',
#   'category': 'Technology',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2014-12-31',
#   'goal': 20000000.0,
#   'launched': '2014-11-06 13:51:26',
#   'pledged': 4.0,
#   'state': 'failed',
#   'backers': 4,
#   'country': 'US',
#   'usd pledged': 4.0,
#   'usd_pledged_real': 4.0},
#  ...]

# %% [markdown]
# ## Question 6

# %%
# nombre de projet ayant "Sport" dans leur nom
#méthode 1
nb_Sport_projects = collection.find({"name" : {"$regex" : "Sport"}}).count()
nb_Sport_projects
# Out:
# /tmp/ipykernel_12/2446262478.py:2: DeprecationWarning: count is deprecated. Use Collection.count_documents instead.
#   nb_Sport_projects = collection.find({"name" : {"$regex" : "Sport"}}).count()
# 321

# %%
# méthode 2
nb_Sport_projects = collection.count_documents({"name" : {"$regex" : "Sport"}})
nb_Sport_projects
# Out:
# 321
